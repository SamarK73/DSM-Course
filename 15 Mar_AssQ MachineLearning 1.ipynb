# %% [markdown]
# # Q1- Explain the following with an example
# 1) Artificial Inteligence
# 2) Machine Learning
# 3) Deep Learning

# %% [markdown]
# ## 1. Artificail Learning:
# Smart applications that can perform its own task without any human intervention.
#
# Example: Social media companies know that their users are their product, so they use AI to connect those users to the advertisers and marketers that have identified their profiles as key targets. Social media AI also has the ability to understand the sort of content a user resonates with and suggests similar content to them.
#
# ## 2. Machine Learning:
# Machine Learning is a subset of AI. It provides stats tool to learn, analyze, visualize and devlope predictive models from the data.
#
# Example: In case of purchasing on Amazon, based on Recomendation system Amazon recommends related product to purchase.
#
#
# ## 3. Deep Learning:
# Deep learning is a subset of Machine Learning
# Deep Learning is often thought to be a more advanced kind of ML because it learns through representation, but the data does not need to be structured.
# Example: Image recgnition

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Q2- What is supervised Learning? List some examples of supervised learning.

# %% [markdown]
# Supervised Learning is one of the type of Machine Learning. In supervised learning we are going to solve 2 types of problems, classification and regression.
# 1. Classification: The Classification algorithm is a Supervised Learning technique that is used to identify the category of new observations on the basis of training data. In Classification, a program learns from the given dataset or observations and then classifies new observation into a number of classes or groups. Such as, Yes or No, 0 or 1, Spam or Not Spam, cat or dog, etc.
#
# The best example of an ML classification algorithm is Email Spam Detector.
#
# 2. Regression: Regression analysis is a statistical method to model the relationship between a dependent (target) and independent (predictor) variables with one or more independent variables. More specifically, Regression analysis helps us to understand how the value of the dependent variable is changing corresponding to an independent variable when other independent variables are held fixed.
# Example:Regression analysis is a statistical method to model the relationship between a dependent (target) and independent (predictor) variables with one or more independent variables. More specifically, Regression analysis helps us to understand how the value of the dependent variable is changing corresponding to an independent variable when other independent variables are held fixed

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Q3. What is unsupervised learning? List some examples of unsupervised learnings.

# %% [markdown]
# As the name suggests, unsupervised learning is a machine learning technique in which models are not supervised using training dataset. Instead, models itself find the hidden patterns and insights from the given data.
# Examples
# 1. Market Segmentation: Sales organizations can cluster or group their users into multiple segments on the basis of their prior billed items.
# 2. Identifying Accident Prone Areas: Unsupervised machine learning models can be used to identify accident-prone areas and introduce safety measures based on the intensity of those accidents.

# %% [markdown]
# # Q4- What is the difference between AI, ML, DL, and DS?

# %% [markdown]
# Artificial Intelligence (AI) Smart applications that can perform its own task without any human intervention.
#
# Machine Learning (ML) is a subset of AI; it provides us statistical tools/techniques like Supervised, Unsupervised, and Reinforcement learning to explore and analyze the data.
#
# Deep Learning (DL) is further a subset of ML, and the main idea behind it is to make machines learn by mimicking the human brain. Here, we create a multi neural network architecture with the help of different techniques like ANN, CNN, and RNN.
#
# Data Science (DS) is basically drawing insights from structured and unstructured data either by using ML or DL or without these techniques. We can even use different visualization tools, statistics, and probability to gain these insights. As a Data Scienctist you have to work in AI, ML and DL.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Q5- What are the main differences between supervised, unsupervised, and semi-supervised learning?

# %% [markdown]
# 1.
# a.Supervised ML learns by using labelled data.
# b.Unsupervised ML trained using unlabelled data without any guidance.
# c.Semi supervised ML is a combination of supervised and unsupervised ML
#
# 2.
# a.Supervised have classification and regression types of problems.
# b.Unsupervised have association and clustering types of problems
# c.Initially model will be trained by supervised dataset and later on it will be in the form of cluster and groups.

# %% [markdown]
# # Q6- What is train, test and validation split? Explain the importance of each term.

# %% [markdown]
# Training Dataset: Training dataset specifically used to train the model
# Validation: We specifically perform hyper parameter tuning of the model. means we tune some parameter of the model so that our model accuracy increases.
# Test dataset: specifically we test the model means we will see how the model will perform with respect to the accuracy.

# %% [markdown]
# # Q7- How can unsupervised learning be used in anomaly detection?

# %% [markdown]
# Anomaly detection techniques of unsupervised nature assume that normal data points occur considerably more frequently than anomalous data points. This assumption is used to classify data points that occur less frequently as anomalies. Unsupervised techniques assign each data point a score instead of a label.

# %% [markdown]
# # Q8- List down some commonly used supervised learning algorithms and unsupervised learning algorithms.

# %% [markdown]
# # Supervised learning algorithms
# 1. Decision Tree
# 2. Logistic Regression
# 3. Linear regression
# 4. support vector machine
# # Unsupervised learning algorithms
# 1. k-means clustering
# 2. hierarchical clustering
# 3. apriori algorithm
