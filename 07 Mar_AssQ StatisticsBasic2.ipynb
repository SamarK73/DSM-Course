# %% [markdown]
# # Q1. What are the three measures of central tendency?

# %% [markdown]
# ##
# Mean:
#
# The arithmetic mean of a dataset (which is different from the geometric mean) is the sum of all values divided by the total number of values. It’s the most commonly used measure of central tendency because all values are used in the calculation. Outliers can significantly increase or decrease the mean when they are included in the calculation. Since all values are used to calculate the mean, it can be affected by extreme outliers.
#
# Median:
#
# The median of a dataset is the value that’s exactly in the middle when it is ordered from low to high. It is a robust measure of central tendency that is not affected by outliers, and it provides information about the middle value of the distribution.
#
# Mode:
#
# The mode is the most frequently occurring value in the dataset. It’s possible to have no mode, one mode, or more than one mode. To find the mode, sort your dataset numerically or categorically and se

# %% [markdown]
# # Q2. What is the difference between the mean, median, and mode? How are they used to measure the central tendency of a dataset?

# %% [markdown]
# The difference between mean, median and mode are: Mean is the average value of the given observations. Median is the middle value of the given observations. Mode is the most repeated value in the given observation.
#
# All three measures of central tendency are useful for different types of data and situations. The mean is often used for continuous data that is normally distributed, while the median is used for skewed data or when there are outliers. The mode is useful for data with a clear peak or cluster of values.
#
# The mean, median, and mode are all measures of central tendency that provide different information about the dataset. The choice of which measure to use depends on the type of data and the context of the analysis.

# %% [markdown]
# # Q3. Measure the three measures of central tendency for the given height data:
#         [178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]

# %%
import numpy as np

import statistics as st

height = [178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]

mean = np.mean(height)
print("Mean", mean)


median = np.median(height)
print("Median", median)


mode = st.mode(height)
print("Mode", mode)
# Out:
# Mean 177.01875
# Median 177.0
# Mode 178

# %% [markdown]
# # Q4. Find the standard deviation for the given data:
#     [178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]

# %%
import numpy as np

import statistics as st

height = [178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]

# Standard deviation calculation
SD = np.std(height)
SD
# Out:
# 1.7885814036548633

# %% [markdown]
# # Q5. How are measures of dispersion such as range, variance, and standard deviation used to describe the spread of a dataset? Provide an example.

# %% [markdown]
# # Range :
#
# Range is the most straightforward measure of variability to calculate and the simplest to understand. The range of a dataset is the difference between the largest and smallest values in that dataset.
#
# Dataset 1 = 20,21,22, 25, 26, 29,33,34,38
# Dataset 2 = 11,16,19,21,23,24,28,32,39,52
#
# For example, in the two datasets above, dataset 1 has a range of 20 – 38 = 18 while dataset 2 has a range of 11 – 52 = 41. Dataset 2 has a broader range and, hence, more variability than dataset 1.
#
# It is based on only the two most extreme values in the dataset, which makes it very susceptible to outliers.
#
# # Variance :
#
#  Because it’s usually impossible to measure an entire population, statisticians use the equation for sample variances much more frequently.
#
# Equation for the sample variance.
#
# ![image.png](attachment:image.png)
#
# In the equation, s2 is the sample variance, and M is the sample mean. N-1 in the denominator corrects for the tendency of a sample to underestimate the population variance.
#
# Example: I will calculate variance for a sample of dataset with 17 observations in the table below:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Because the calculations use the squared differences, the variance is in squared units rather the original units of the data. While higher values of the variance indicate greater variability, there is no intuitive interpretation for specific values.

# %% [markdown]
# # Standard Deviation:
#
# The standard deviation is the standard or typical difference between each data point and the mean. When the values in a dataset are grouped closer together, you have a smaller standard deviation. On the other hand, when the values are spread out more, the standard deviation is larger because the standard distance is greater.
# The standard deviation is just the square root of the variance. Recall that the variance is in squared units. Hence, the square root returns the value to the natural units. The symbol for the standard deviation as a population parameter is σ.  To calculate the standard deviation, calculate the variance as shown above, and then take the square root of it. You have the standard deviation!
# In the above example we calculated variance 201 so the standard deviation will be square root of 201, which is 14.177

# %% [markdown]
# # Q6. What is a Venn diagram?

# %% [markdown]
# A Venn diagram is an illustration that uses circles to show the relationships among things or finite groups of things. Things that have commonalities are shown as overlapping circles while things that are distinct stand alone.
# Venn diagrams help to visually represent the similarities and differences between two concepts
# ![image.png](attachment:image.png)

# %% [markdown]
# # Q7. For the two given sets A = (2,3,4,5,6,7) & B = (0,2,6,8,10). Find:
# (i) A  B (Intersection)
# (ii) A ⋃ B

# %% [markdown]
# (i) A intersection B = (2,6)
# (ii) A U B = (0,2,3,4,5,6,7,8,10)

# %% [markdown]
# # Q8. What do you understand about skewness in data?

# %% [markdown]
# skewness is the measure of how much the probability distribution of a random variable deviates from the normal distribution/symmetrical(without any skewness). There are three types of skewness:
#
# #Normal/symmetrical skewness:
# The normal distribution is the probability distribution without any skewness.
#
# #Positive/right skewness :
# The probability distribution with its tail on the right side is a positively skewed distribution.
#
# #Negative/left skewness:
# The probability distribution with its tail on the left side is a negatively skewed distribution.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Q9. If a data is right skewed then what will be the position of median with respect to mean?

# %% [markdown]
# If the data is right skewed with the long tail on its right side. The value of skewness for a positively skewed distribution is greater than zero. When the distribution is right skewed, the value of mean is the greatest one, followed by the median and then by mode.
# ![image.png](attachment:image.png)

# %% [markdown]
# # Q10. Explain the difference between covariance and correlation. How are these measures used in statistical analysis?

# %% [markdown]
# 1.
# Covariance is an indicator of the extent to which 2 random variables are dependent on each other. A higher number denotes      higher dependency.
# Correlation is a statistical measure that indicates how strongly two variables are related.
#
# 2.
# covariance values lies in the range of -∞ and +∞.
# Correlation is limited to values between the range -1 and +1
#
# 3.
# Covariance get change after change in scale.
# Corelation does not affect when change in scale.
#
# 4.
# Covariance is not unit free measure.
# Corelation is unit free measure.

# %%
import numpy as np

x=[1,2,3,4,5]
y=[5,9,14,13,16]

# Calculating Covariance
covariance_s = np.cov(x,y)[0][1]
covariance_s
# Out:
# 6.5

# %%
# Calculting Corelation
corr=np.corrcoef(x,y)[0][1]
corr
# Out:
# 0.9357604759733028

# %% [markdown]
# Covariance is a statistical term that refers to a systematic relationship between two random variables in which a change in the other reflects a change in one variable. Its value can range from -∞ from +∞.
# The greater this number, the more reliant the relationship. Positive covariance denotes a direct relationship and is represented by a positive number.
# Negative covariance indicates inverse relationship between two variables
#
# correlation is a measure that determines the degree to which two or more random variables move in sequence. When an equivalent movement of another variable reciprocates the movement of one variable in some way or another during the study of two variables, the variables are said to be correlated. Positive correlation occurs when two variables move in the same direction. When variables move in the opposite direction, they are said to be negatively correlated.

# %% [markdown]
# # Q11. What is the formula for calculating the sample mean? Provide an example calculation for a dataset.

# %% [markdown]
# The sample mean formula is written as
#
# Sample Mean = (Sum of terms) ÷ (Number of Terms) = Summation xi/n
#
# Summation xi = Sum of terms
# n = number of terms

# %% [markdown]
# Find the sample mean of 60, 57, 109, 50.

# %%
x=[60,57,109,50]

mean = np.mean(x)

print(mean)
# Out:
# 69.0

# %% [markdown]
# # Q12. For a normal distribution data what is the relationship between its measure of central tendency?

# %% [markdown]
# For a normal distribution data, the mean, median, and mode are all equal. This is because a normal distribution is symmetric around its mean, and the mean is located at the peak of the distribution. Additionally, the tails of a normal distribution decay exponentially, which means that the mode and median are also located at the same point as the me

# %% [markdown]
# # Q13. How is covariance different from correlation?

# %% [markdown]
# Covariance and correlation greatly aid in understanding the relationship between two continuous variables. Covariance indicates whether two variables fluctuate in the same (positive covariance) or opposite direction (negative covariance). The numerical value of covariance has no importance; only the sign is relevant. Correlation, on the other hand, describes how a change in one variable leads to a change in the percentage of the second variable. Correlation ranges from -1 to +1. If the correlation value is 0, it suggests that there is no linear link between the variables, but another functional relationship may exist.

# %% [markdown]
# # Q14. How do outliers affect measures of central tendency and dispersion? Provide an example.

# %% [markdown]
#  Outliers affect the mean value of the data but have little effect on the median or mode of a given set of data.
#  The presence of outlier can pull the measure of central tendency value towards their direction.
#  For example, in a dataset one day temperatures where most of temperature range between 15 deg to 35 deg, an outlier of 70 deg will significantly increase the average temperature.

# %%
# temp data
temp_data = [15,18,19,20,25,30,35,70]

# Mean, median
mean = np.mean(temp_data)
median = np.median(temp_data)

# Measure of dispersion

range = np.max(temp_data)-np.min(temp_data)
variance = np.var(temp_data)
std_dev = np.std(temp_data)

#Results

print("Temperature Data", temp_data)
print("Mean", mean)
print("Median", median)
print("Range",range)
print("Variance", variance)
print("Standard Deviation", std_dev)
# Out:
# Temperature Data [15, 18, 19, 20, 25, 30, 35, 70]
# Mean 29.0
# Median 22.5
# Range 55
# Variance 279.0
# Standard Deviation 16.703293088490067

# %%
np.mean(temp_data[0:7])
# Out:
# 23.142857142857142
